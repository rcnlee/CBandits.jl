# %%
include("performance.jl")
# Out:
# GPPerformance

# %%
using GPPerformance
using Plots; gr()
# Out:
# Plots.GRBackend()

# %%
# GaussianProcesses.jl

# %%
study = GPNvsTime()
# Out:
# GPPerformance.GPNvsTime
#   ds: Array{Int64}((2,)) [2, 3]
#   ns: Array{Int64}((10,)) [10, 20, 50, 100, 200, 500, 700, 1000, 1500, 2000]
#   seeds: Array{Int64}((5,)) [1, 2, 3, 4, 5]

# %%
gp_result = run_study(study)
# Out:
# GPPerformance.GPNvsTimeResult(100×4 DataFrames.DataFrame
# │ Row │ dims │ n    │ seed │ cputime_us │
# ├─────┼──────┼──────┼──────┼────────────┤
# │ 1   │ 2    │ 10   │ 1    │ 180.0      │
# │ 2   │ 2    │ 10   │ 2    │ 110.0      │
# │ 3   │ 2    │ 10   │ 3    │ 57.0       │
# │ 4   │ 2    │ 10   │ 4    │ 50.0       │
# │ 5   │ 2    │ 10   │ 5    │ 53.0       │
# │ 6   │ 2    │ 20   │ 1    │ 525.0      │
# │ 7   │ 2    │ 20   │ 2    │ 350.0      │
# │ 8   │ 2    │ 20   │ 3    │ 392.0      │
# │ 9   │ 2    │ 20   │ 4    │ 363.0      │
# │ 10  │ 2    │ 20   │ 5    │ 351.0      │
# │ 11  │ 2    │ 50   │ 1    │ 1286.0     │
# ⋮
# │ 89  │ 3    │ 1000 │ 4    │ 691615.0   │
# │ 90  │ 3    │ 1000 │ 5    │ 609363.0   │
# │ 91  │ 3    │ 1500 │ 1    │ 2.05803e6  │
# │ 92  │ 3    │ 1500 │ 2    │ 2.07812e6  │
# │ 93  │ 3    │ 1500 │ 3    │ 2.04216e6  │
# │ 94  │ 3    │ 1500 │ 4    │ 2.09816e6  │
# │ 95  │ 3    │ 1500 │ 5    │ 2.05527e6  │
# │ 96  │ 3    │ 2000 │ 1    │ 4.99438e6  │
# ...

# %%
plot(gp_result)

# %%
# GaussianProcesses2.jl

# %%
study = GP2NvsTime()
# Out:
# GPPerformance.GP2NvsTime
#   ds: Array{Int64}((2,)) [2, 3]
#   ns: Array{Int64}((10,)) [10, 20, 50, 100, 200, 500, 700, 1000, 1500, 2000]
#   seeds: Array{Int64}((5,)) [1, 2, 3, 4, 5]

# %%
gp2_result = run_study(study)
# Out:
# GPPerformance.GP2NvsTimeResult(100×4 DataFrames.DataFrame
# │ Row │ dims │ n    │ seed │ cputime_us │
# ├─────┼──────┼──────┼──────┼────────────┤
# │ 1   │ 2    │ 10   │ 1    │ 572.0      │
# │ 2   │ 2    │ 10   │ 2    │ 557.0      │
# │ 3   │ 2    │ 10   │ 3    │ 564.0      │
# │ 4   │ 2    │ 10   │ 4    │ 386.0      │
# │ 5   │ 2    │ 10   │ 5    │ 346.0      │
# │ 6   │ 2    │ 20   │ 1    │ 917.0      │
# │ 7   │ 2    │ 20   │ 2    │ 992.0      │
# │ 8   │ 2    │ 20   │ 3    │ 936.0      │
# │ 9   │ 2    │ 20   │ 4    │ 903.0      │
# │ 10  │ 2    │ 20   │ 5    │ 914.0      │
# │ 11  │ 2    │ 50   │ 1    │ 4635.0     │
# ⋮
# │ 89  │ 3    │ 1000 │ 4    │ 1.99125e6  │
# │ 90  │ 3    │ 1000 │ 5    │ 1.98678e6  │
# │ 91  │ 3    │ 1500 │ 1    │ 4.90034e6  │
# │ 92  │ 3    │ 1500 │ 2    │ 4.97439e6  │
# │ 93  │ 3    │ 1500 │ 3    │ 5.44579e6  │
# │ 94  │ 3    │ 1500 │ 4    │ 5.72604e6  │
# │ 95  │ 3    │ 1500 │ 5    │ 5.95386e6  │
# │ 96  │ 3    │ 2000 │ 1    │ 1.08108e7  │
# ...

# %%
plot(gp2_result)

# %%
plot(gp_result, gp2_result)
