# %%
using CBandits
using POMDPs
using DataFrames
using Plots; pyplot()
# Out:
# WARNING: using Plots.PyPlot in module Main conflicts with an existing identifier.
# Plots.PyPlotBackend()

# %%
## Grid
### Uniform

# %%
b = GPUCBGrid(; actiondistr=UniformActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, WideBump())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
b = GPUCBGrid(; actiondistr=UniformActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, NarrowBump())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
b = GPUCBGrid(; actiondistr=UniformActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, TwoBumps())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
b = GPUCBGrid(; actiondistr=UniformActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, ThreeBumps())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
b = GPUCBGrid(; actiondistr=UniformActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, Sinc())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
## Grid
### Gaussian

# %%
b = GPUCBGrid(; actiondistr=GaussianActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, WideBump())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
b = GPUCBGrid(; actiondistr=GaussianActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, NarrowBump())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
b = GPUCBGrid(; actiondistr=GaussianActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, TwoBumps())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
b = GPUCBGrid(; actiondistr=GaussianActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, ThreeBumps())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
b = GPUCBGrid(; actiondistr=GaussianActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, Sinc())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
## k=100
### Uniform

# %%
b = GPUCB(; actiondistr=UniformActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, WideBump())
animate(gp_result, "./gpucb_uniform_widebump.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gpucb_uniform_widebump.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gpucb_uniform_widebump.gif")

# %%
b = GPUCB(; actiondistr=UniformActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, NarrowBump())
animate(gp_result, "./gpucb_uniform_narrowbump.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gpucb_uniform_narrowbump.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gpucb_uniform_narrowbump.gif")

# %%
b = GPUCB(; actiondistr=UniformActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, TwoBumps())
animate(gp_result, "./gpucb_uniform_twobumps.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gpucb_uniform_twobumps.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gpucb_uniform_twobumps.gif")

# %%
b = GPUCB(; actiondistr=UniformActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, ThreeBumps())
animate(gp_result, "./gpucb_uniform_threebumps.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gpucb_uniform_threebumps.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gpucb_uniform_threebumps.gif")

# %%
b = GPUCB(; actiondistr=UniformActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, Sinc())
animate(gp_result, "./gpucb_uniform_sinc.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gpucb_uniform_sinc.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gpucb_uniform_sinc.gif")

# %%
## k=100
### Gaussian

# %%
b = GPUCB(; actiondistr=GaussianActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, WideBump())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
b = GPUCB(; actiondistr=GaussianActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, NarrowBump())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
b = GPUCB(; actiondistr=GaussianActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, TwoBumps())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
b = GPUCB(; actiondistr=GaussianActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, ThreeBumps())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
b = GPUCB(; actiondistr=GaussianActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, Sinc())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
## k=1
### Uniform

# %%
b = GPUCB(; k=1, actiondistr=UniformActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, WideBump())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
b = GPUCB(; k=1, actiondistr=UniformActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, NarrowBump())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
b = GPUCB(; k=1, actiondistr=UniformActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, TwoBumps())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
b = GPUCB(; k=1, actiondistr=UniformActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, ThreeBumps())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
b = GPUCB(; k=1, actiondistr=UniformActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, Sinc())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
## k=1
### Gaussian

# %%
b = GPUCB(; k=1, actiondistr=GaussianActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, WideBump())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
b = GPUCB(; k=1, actiondistr=GaussianActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, NarrowBump())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
b = GPUCB(; k=1, actiondistr=GaussianActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, TwoBumps())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
b = GPUCB(; k=1, actiondistr=GaussianActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, ThreeBumps())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
b = GPUCB(; k=1, actiondistr=GaussianActions(), mean_init=2.0, outs=Set([:plot]))
gp_result = POMDPs.solve(b, Sinc())
animate(gp_result, "./gptest.gif")
# Out:
# INFO: Saved animation to /Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif
# Plots.AnimatedGif("/Users/rlee18/.julia/v0.6/CBandits/notebooks/gptest.gif")

# %%
study = GPOptimMetricStudy(; actiondistr=UniformActions(), G=ThreeBumps(), mean_inits=[8.0,5.0,3.0,2.0,0.0])
result = run_study(study)
# Out:
# CBandits.GPOptimMetricStudyResult(Any["Random"=>[0.598966; 1.23448; … ; 59.4696; 60.0976], "PW"=>[0.598966; 1.19029; … ; 39.1036; 39.7322], "SB"=>[0.598966; 1.22777; … ; 35.1705; 35.4713], "GPUCB-Grid"=>[0.598966; 1.15172; … ; 27.3297; 27.4234], "GPUCB-8"=>[0.598966; 1.30287; … ; 38.6165; 38.8263], "GPUCB-5"=>[0.598966; 1.29987; … ; 34.847; 35.0229], "GPUCB-3"=>[0.598966; 1.30169; … ; 32.2752; 32.4256], "GPUCB-2"=>[0.598966; 1.30003; … ; 30.8331; 30.9984], "GPUCB-0"=>[0.598966; 1.11123; … ; 27.4826; 27.5987]], Any["Random"=>[0.615791; 0.473157; … ; 0.208132; 0.206447], "PW"=>[0.615791; 0.615791; … ; 0.126682; 0.138368], "SB"=>[0.615791; 0.490121; … ; 0.104873; 0.105745], "GPUCB-Grid"=>[0.615791; 0.628785; … ; 0.0349194; 0.0354036], "GPUCB-8"=>[0.615791; 0.693332; … ; 0.0545525; 0.049844], "GPUCB-5"=>[0.615791; 0.69015; … ; 0.0504687; 0.0496829], "GPUCB-3"=>[0.615791; 0.69015; … ; 0.0432253; 0.0422314], "GPUCB-2"=>[0.615791; 0.691448; … ; 0.0363547; 0.0355652], "GPUCB-0"=>[0.615791; 0.606961; … ; 0.0424036; 0.0416329]])

# %%
plot(result, :cum_regret)

# %%
plot(result, :simple_regret)

# %%
study = GPOptimMetricStudy(; actiondistr=UniformActions(), G=TwoBumps(), mean_inits=[8.0,5.0,3.0,2.0,0.0])
result = run_study(study)
# Out:
# CBandits.GPOptimMetricStudyResult(Any["Random"=>[0.770439; 1.60326; … ; 77.3024; 78.1034], "PW"=>[0.770439; 1.53324; … ; 45.6707; 46.4661], "SB"=>[0.770439; 1.59629; … ; 36.9722; 37.2305], "GPUCB-Grid"=>[0.770439; 1.47943; … ; 25.5107; 25.5483], "GPUCB-8"=>[0.770439; 1.6761; … ; 39.918; 40.0528], "GPUCB-5"=>[0.770439; 1.67263; … ; 34.7469; 34.8461], "GPUCB-3"=>[0.770439; 1.67444; … ; 31.4877; 31.5718], "GPUCB-2"=>[0.770439; 1.67591; … ; 29.8105; 29.898], "GPUCB-0"=>[0.770439; 1.45901; … ; 25.2078; 25.272]], Any["Random"=>[0.787264; 0.638264; … ; 0.143659; 0.143853], "PW"=>[0.787264; 0.787264; … ; 0.10582; 0.110984], "SB"=>[0.787264; 0.663369; … ; 0.050439; 0.0469259], "GPUCB-Grid"=>[0.787264; 0.801523; … ; 0.0224946; 0.0226299], "GPUCB-8"=>[0.787264; 0.894959; … ; 0.0198848; 0.0193586], "GPUCB-5"=>[0.787264; 0.891437; … ; 0.0214371; 0.0207236], "GPUCB-3"=>[0.787264; 0.891437; … ; 0.0192609; 0.0196584], "GPUCB-2"=>[0.787264; 0.892845; … ; 0.0214258; 0.0213992], "GPUCB-0"=>[0.787264; 0.778564; … ; 0.0184924; 0.0177021]])

# %%
plot(result, :cum_regret)

# %%
plot(result, :simple_regret)

# %%
study = GPOptimMetricStudy(; actiondistr=UniformActions(), G=Sinc(), mean_inits=[8.0,5.0,3.0,2.0,0.0])
result = run_study(study)
# Out:
# CBandits.GPOptimMetricStudyResult(Any["Random"=>[0.954931; 1.9375; … ; 96.3553; 97.3319], "PW"=>[0.954931; 1.90222; … ; 78.8783; 79.8541], "SB"=>[0.954931; 1.92872; … ; 75.8315; 76.4391], "GPUCB-Grid"=>[0.954931; 1.9217; … ; 36.7594; 36.8009], "GPUCB-8"=>[0.954931; 1.94844; … ; 54.846; 54.9418], "GPUCB-5"=>[0.954931; 1.9501; … ; 48.4069; 48.4862], "GPUCB-3"=>[0.954931; 1.94651; … ; 45.402; 45.4807], "GPUCB-2"=>[0.954931; 1.94846; … ; 44.1309; 44.217], "GPUCB-0"=>[0.954931; 1.93977; … ; 41.0164; 41.0991]], Any["Random"=>[0.971756; 0.940923; … ; 0.297503; 0.295787], "PW"=>[0.971756; 0.971756; … ; 0.47356; 0.468308], "SB"=>[0.971756; 0.945182; … ; 0.443932; 0.43812], "GPUCB-Grid"=>[0.971756; 0.964323; … ; 0.0357468; 0.036137], "GPUCB-8"=>[0.971756; 0.984382; … ; 0.0272205; 0.0274088], "GPUCB-5"=>[0.971756; 0.984424; … ; 0.0331894; 0.0329719], "GPUCB-3"=>[0.971756; 0.984334; … ; 0.0312702; 0.0307979], "GPUCB-2"=>[0.971756; 0.984307; … ; 0.0413257; 0.0412118], "GPUCB-0"=>[0.971756; 0.964137; … ; 0.0505215; 0.049857]])

# %%
plot(result, :cum_regret)

# %%
plot(result, :simple_regret)
